# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import time, os
import numpy as np
import requests
import re
import random

# %%
req_headers = {
    'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8',
    'accept-encoding': 'gzip, deflate, br',
    'accept-language': 'en-US,en;q=0.8',
    'upgrade-insecure-requests': '1',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/61.0.3163.100 Safari/537.36'
}

# %%
def get_property_urls(link):
    # omg thank god for some dude on github for this req_header 0 CAPTCHAS i owe you my life
    
    req_headers = {
        'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8',
        'accept-encoding': 'gzip, deflate, br',
        'accept-language': 'en-US,en;q=0.8',
        'upgrade-insecure-requests': '1',
        'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/61.0.3163.100 Safari/537.36'
    }


    r = requests.get(link, headers=req_headers)
    soup = BeautifulSoup(r.content, 'html.parser')

    table = soup.find('ul', class_='photo-cards photo-cards_wow photo-cards_short')
    li_tags = table.find_all('li')
    properties = [item.find('div', class_='list-card-info')for item in li_tags]

    property_urls = []

    for item in properties:
        if item != None:
            property_extensions = item.find('a')['href']
            property_urls.append(property_extensions)
            
    return property_urls

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
path = '/Users/collinswestnedge/Downloads/chromedriver'
driver = webdriver.Chrome(path)

driver.get('https://www.eventScribe.net/2022/38thNCAC/login.asp')

# driver.find_element_by_id("login_field").send_keys(username)
# # find password input field and insert password as well
# driver.find_element_by_id("password").send_keys(password)
# # click login button
# driver.find_element_by_name("commit").click()
# Out:
# <ipython-input-48-e35dca186cee>:4: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(path)

# %%
driver.find_element_by_id("AccountEmail").send_keys('slucas@socialsolutions.com')
driver.find_element_by_id("AccountKey").send_keys("XLDCCZML")
# Out:
# <ipython-input-51-538fc7691da1>:1: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_id("AccountEmail").send_keys('slucas@socialsolutions.com')
# <ipython-input-51-538fc7691da1>:2: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_id("AccountKey").send_keys("XLDCCZML")

# %%
# click submit to login
(driver.find_element_by_xpath
                    ("/html/body/div[5]/div/div/div[1]/div/form/div/button").click())
# Out:
# <ipython-input-81-5733c2b07002>:1: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   (driver.find_element_by_xpath

# %%
# navigate to the home page and click
driver.find_element_by_xpath('/html/body/div[1]/div/nav/div/a').click()
# Out:
# <ipython-input-82-8c88f4791406>:1: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   driver.find_element_by_xpath('/html/body/div[1]/div/nav/div/a').click()

# %%
# navigate to the schedule for day 1 (clicked day 1)
driver.find_element_by_xpath('/html/body/div[5]/div[2]/div/div[2]/div[2]/a[1]/div/img').click()
# Out:
# <ipython-input-84-ca909c9f806c>:1: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   driver.find_element_by_xpath('/html/body/div[5]/div[2]/div/div[2]/div[2]/a[1]/div/img').click()

# %%
# view first conference/speaker
driver.find_element_by_xpath('/html/body/div[5]/div[2]/div/ul/li[2]').click()
# Out:
# <ipython-input-88-bd9105b14f37>:1: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   driver.find_element_by_xpath('/html/body/div[5]/div[2]/div/ul/li[2]').click()

# %%
# click on attendees
driver.find_element_by_xpath('/html/body/div[4]/div/div[1]/div[6]/div[2]/a[2]').click()
# Out:
# <ipython-input-89-af69ef753596>:2: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   driver.find_element_by_xpath('/html/body/div[4]/div/div[1]/div[6]/div[2]/a[2]').click()

# %%
page_source = driver.page_source
soup = BeautifulSoup(page_source, 'lxml')
soup.find_all('li')
# Out:
# [<li id="Nav-Item-0"><a class="nav-item-link" href="https://www.eventscribe.net/2022/38thNCAC"><span style="margin-left: 0px;">Home</span></a></li>,
#  <li id="Nav-Item-1"><a class="nav-item-link" href="https://www.nationalcac.org/" target="_blank"><span style="margin-left: 0px;">NCAC Website</span></a></li>,
# ...

# %%
a = soup.find('div', class_='card')
a.find('div', class_='card current-card')
